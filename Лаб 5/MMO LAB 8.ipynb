# %% [markdown]
# Журавлев Н.В., ИУ5-24М, Вариант 5

# %% [markdown]
# **Задание:**
# Для произвольного предложения или текста решите следующие задачи:
# 1.   Токенизация.
# 2.   Частеречная разметка.
# 3.   Лемматизация.
# 4.   Выделение (распознавание) именованных сущностей.
# 5.   Разбор предложения.

# %% [markdown]
# **Текст**

# %%
text = 'Привет, Игорь! Я был рад получить от тебя ответ и прочитать об успехах твоей семьи. Я надеюсь, что ты скоро закончишь работу над своим проектом, и вы сможете приехать к нам в Москву. Мы с женой уже начали составлять список достопримечательностей, которые хотели бы вам показать. В первую очередь мы предлагаем посетить сердце Москвы – Красную площадь. Там расположен Кремль и рядом собор Василия Блаженного. Мы посмотрим на самый большой колокол в России – Царь-Колокол, вес которого составляет 202 тонны. В Москве находится огромное количество музеев и галерей: музей истории, Оружейной палаты, космонавтики, Алмазный фонд, Планетарий и пр. Я уверен, как дизайнеру, тебе будет интересно посетить Третьяковскую галерею и вдохновиться работами известных художников. Если вы приедете с детьми, то можно сходить в Московский зоопарк, на Останкинскую телебашню, в парк ВДНХ. Буду ждать ответа. Твой друг Роман.'

# %% [markdown]
# **Токенизация**

# %% [markdown]
# Токенизация — процесс разделения текста на составляющие (их называют «токенами»). В данной работе текст разделяется на токены по знакам припинания и пробелма, и предложениям.

# %%
# !python -m spacy download ru_core_news_sm
import nltk
nltk.download('punkt')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 806.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 26.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from spacy.lang.ru import Russian
import ru_core_news_sm
nlp = ru_core_news_sm.load()
spacy_text = nlp(text)
spacy_text
# Out:
# Привет, Игорь! Я был рад получить от тебя ответ и прочитать об успехах твоей семьи. Я надеюсь, что ты скоро закончишь работу над своим проектом, и вы сможете приехать к нам в Москву. Мы с женой уже начали составлять список достопримечательностей, которые хотели бы вам показать. В первую очередь мы предлагаем посетить сердце Москвы – Красную площадь. Там расположен Кремль и рядом собор Василия Блаженного. Мы посмотрим на самый большой колокол в России – Царь-Колокол, вес которого составляет 202 тонны. В Москве находится огромное количество музеев и галерей: музей истории, Оружейной палаты, космонавтики, Алмазный фонд, Планетарий и пр. Я уверен, как дизайнеру, тебе будет интересно посетить Третьяковскую галерею и вдохновиться работами известных художников. Если вы приедете с детьми, то можно сходить в Московский зоопарк, на Останкинскую телебашню, в парк ВДНХ. Буду ждать ответа. Твой друг Роман.

# %%
nltk_tk = nltk.WordPunctTokenizer()
nltk_tk.tokenize(text)
# Out:
# ['Привет',
#  ',',
#  'Игорь',
#  '!',
#  'Я',
#  'был',
#  'рад',
#  'получить',
#  'от',
#  'тебя',
#  'ответ',
#  'и',
#  'прочитать',
#  'об',
#  'успехах',
#  'твоей',
#  'семьи',
#  '.',
#  'Я',
#  'надеюсь',
#  ',',
#  'что',
#  'ты',
#  'скоро',
#  'закончишь',
#  'работу',
#  'над',
#  'своим',
#  'проектом',
#  ',',
#  'и',
#  'вы',
#  'сможете',
#  'приехать',
#  'к',
#  'нам',
#  'в',
#  'Москву',
#  '.',
#  'Мы',
#  'с',
#  'женой',
#  'уже',
#  'начали',
#  'составлять',
#  'список',
#  'достопримечательностей',
#  ',',
#  'которые',
#  'хотели',
#  'бы',
#  'вам',
#  'показать',
#  '.',
#  'В',
#  'первую',
#  'очередь',
#  'мы',
#  'предлагаем',
#  'посетить',
#  'сердце',
#  'Москвы',
#  '–',
#  'Красную',
#  'площадь',
#  '.',
#  'Там',
#  'расположен',
#  'Кремль',
#  'и',
#  'рядом',
#  'собор',
#  'Василия',
#  'Блаженного',
#  '.',
#  'Мы',
#  'посмотрим',
#  'на',
#  'самый',
#  'большой',
#  'колокол',
#  'в',
#  'России',
#  '–',
#  'Царь',
#  '-',
# ...

# %%
# Токенизация по предложениям
nltk_tk_sents = nltk.tokenize.sent_tokenize(text)
print(len(nltk_tk_sents))
nltk_tk_sents
# Out:
# 12
# ['Привет, Игорь!',
#  'Я был рад получить от тебя ответ и прочитать об успехах твоей семьи.',
#  'Я надеюсь, что ты скоро закончишь работу над своим проектом, и вы сможете приехать к нам в Москву.',
#  'Мы с женой уже начали составлять список достопримечательностей, которые хотели бы вам показать.',
#  'В первую очередь мы предлагаем посетить сердце Москвы – Красную площадь.',
#  'Там расположен Кремль и рядом собор Василия Блаженного.',
#  'Мы посмотрим на самый большой колокол в России – Царь-Колокол, вес которого составляет 202 тонны.',
#  'В Москве находится огромное количество музеев и галерей: музей истории, Оружейной палаты, космонавтики, Алмазный фонд, Планетарий и пр.',
#  'Я уверен, как дизайнеру, тебе будет интересно посетить Третьяковскую галерею и вдохновиться работами известных художников.',
#  'Если вы приедете с детьми, то можно сходить в Московский зоопарк, на Останкинскую телебашню, в парк ВДНХ.',
#  'Буду ждать ответа.',
#  'Твой друг Роман.']

# %% [markdown]
# **Частеречная разметка**

# %% [markdown]
# Частеречная разметка (Part-of-Speech tagging) – это процесс присвоения каждому слову в тексте определенной метки, соответствующей его грамматической роли.

# %%
for token in spacy_text:
    print('{} - {} - {}'.format(token.text, token.pos_, token.dep_))
# Out:
# Привет - NOUN - ROOT
# , - PUNCT - punct
# Игорь - PROPN - conj
# ! - PUNCT - punct
# Я - PRON - nsubj
# был - AUX - cop
# рад - ADJ - ROOT
# получить - VERB - xcomp
# от - ADP - case
# тебя - PRON - obl
# ответ - NOUN - obj
# и - CCONJ - cc
# прочитать - VERB - conj
# об - ADP - case
# успехах - NOUN - obl
# твоей - DET - det
# семьи - NOUN - nmod
# . - PUNCT - punct
# Я - PRON - nsubj
# надеюсь - VERB - ROOT
# , - PUNCT - punct
# что - SCONJ - mark
# ты - PRON - nsubj
# скоро - ADV - advmod
# закончишь - VERB - ccomp
# работу - NOUN - obj
# над - ADP - case
# своим - DET - det
# проектом - NOUN - nmod
# , - PUNCT - punct
# и - CCONJ - cc
# вы - PRON - nsubj
# сможете - VERB - conj
# приехать - VERB - xcomp
# к - ADP - case
# нам - PRON - obl
# в - ADP - case
# Москву - PROPN - obl
# . - PUNCT - punct
# Мы - PRON - nsubj
# с - ADP - case
# женой - NOUN - nmod
# уже - ADV - advmod
# начали - VERB - ROOT
# составлять - VERB - xcomp
# список - NOUN - obj
# ...

# %% [markdown]
# **Лемматизация**

# %% [markdown]
# Лемматизация - это процесс приведения слова к его базовой форме (лемме) путем удаления окончаний и суффиксов. Это помогает унифицировать различные формы слова и улучшить точность анализа.

# %%
for token in spacy_text:
      print(token, token.lemma_)
# Out:
# Привет привет
# , ,
# Игорь игорь
# ! !
# Я я
# был быть
# рад рад
# получить получить
# от от
# тебя тебя
# ответ ответ
# и и
# прочитать прочитать
# об об
# успехах успех
# твоей твой
# семьи семья
# . .
# Я я
# надеюсь надеяться
# , ,
# что что
# ты ты
# скоро скоро
# закончишь закончишь
# работу работа
# над над
# своим свой
# проектом проект
# , ,
# и и
# вы вы
# сможете смочь
# приехать приехать
# к к
# нам нам
# в в
# Москву москва
# . .
# Мы мы
# с с
# женой жена
# уже уже
# начали начать
# составлять составлять
# список список
# достопримечательностей достопримечательность
# , ,
# которые которые
# хотели хотеть
# бы бы
# вам вам
# показать показать
# . .
# В в
# первую первый
# очередь очередь
# мы мы
# предлагаем предлагать
# посетить посетить
# сердце сердце
# Москвы москва
# – –
# Красную красный
# площадь площадь
# . .
# Там там
# расположен расположен
# Кремль кремль
# и и
# рядом рядом
# собор собор
# Василия василий
# Блаженного блаженный
# . .
# Мы мы
# ...

# %% [markdown]
# **Выделение (распознавание) именованных сущностей**

# %% [markdown]
# Задача извлечения именованных сущностей сводится к выявлению отрезков текста, которые являются именами собственными, и их категоризации по типу сущности. Результаты решения можно в дальнейшем использовать для снижения разреженности данных при классификации текста

# %%
for ent in spacy_text.ents:
    print(ent.text, ent.label_)
# Out:
# Игорь PER
# Москву LOC
# Москвы LOC
# Красную площадь LOC
# Кремль LOC
# России LOC
# Царь-Колокол LOC
# Москве LOC
# Оружейной палаты ORG
# Алмазный фонд ORG
# Планетарий PER
# Третьяковскую галерею LOC
# Московский зоопарк ORG
# Останкинскую телебашню LOC
# ВДНХ ORG
# Роман PER

# %%
from spacy import displacy
import spacy
displacy.render(spacy_text, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Привет,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Игорь
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ! Я был рад получить от тебя ответ и прочитать об успехах твоей семьи. Я надеюсь, что ты скоро закончишь работу над своим проектом, и вы сможете приехать к нам в
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Москву
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ...

# %%
print(spacy.explain("LOC"))
print(spacy.explain("PER"))
print(spacy.explain("ORG"))
# Out:
# Non-GPE locations, mountain ranges, bodies of water
# Named person or family.
# Companies, agencies, institutions, etc.

# %% [markdown]
# **Разбор предложения**

# %%
from spacy import displacy
displacy.render(spacy_text, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="7705e9f67d774a6c9cbd35afa41b6597-0" class="displacy" width="23500" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Привет,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Игорь!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
# ...
